# %% [markdown]
# # estimate the c.m. width of two protons in swimming in the Fermi sea

# %%
import sys ; sys.path.insert(0, '../')
from notebook_tools import *
from scipy import optimize
import matplotlib.mlab as mlab
import matplotlib.patches as patches
# %matplotlib inline

# %%
# --- - -- ---- - -- ---- - -- ---- - -- -
# June-17,2018
# generate a 3-vector randomly in a sphere of radius r
def generate_in_Fermi_sphere(R=1,return_type='(x,y,z)'):
    u = np.random.uniform(0,1)
    cos_theta = np.random.uniform(-1,1)
    phi = np.random.uniform(0,2*np.pi)

    
    r = R * np.cbrt( u )
    theta = np.arccos(cos_theta)
    sin_theta = np.sqrt(1 - np.square(cos_theta))
    
    x = r * sin_theta * np.cos(phi)
    y = r * sin_theta * np.sin(phi)
    z = r * cos_theta
    
    if return_type=='(x,y,z)':
        return np.array([x,y,z])
    elif return_type=='(x,y,z,r,theta,phi)':
        return np.array([x,y,z,r,theta,phi])        
# --- - -- ---- - -- ---- - -- ---- - -- -

# %%
# hyperparameters
Nevents = 5000
kF_array = linspace(200,300,11) # MeV/c

# %%
# main for loop
results = pd.DataFrame(columns=['kF','sigma_cm_x','sigma_cm_y','sigma_cm_z'])
results_kF_dict = dict()
for kF in kF_array:
    print 'running kF=',kF,'MeV/c'
    results_kF = pd.DataFrame(columns=['P1_x','P1_y','P1_z'
                                ,'P2_x','P2_y','P2_z'
                                ,'Pcm_x','Pcm_y','Pcm_z'])
    for event in range(Nevents):

        P1 = generate_in_Fermi_sphere( R=kF , return_type='(x,y,z,r,theta,phi)')
        P2 = generate_in_Fermi_sphere( R=kF , return_type='(x,y,z,r,theta,phi)')
        Pcm = P1 + P2

        results_kF = results_kF.append(pd.DataFrame({'P1_x':P1[0],'P1_y':P1[1],'P1_z':P1[2],'P1':P1[3],'P1_theta':P1[4],'P1_phi':P1[5]
                                           ,'P2_x':P2[0],'P2_y':P2[1],'P2_z':P2[2],'P2':P2[3],'P2_theta':P2[4],'P2_phi':P2[5]
                                           ,'Pcm_x':Pcm[0],'Pcm_y':Pcm[1],'Pcm_z':Pcm[2],'Pcm':np.sqrt(np.sum(np.square(Pcm)))}
                                          ,index=[event]))
    results_kF_dict[kF] = results_kF
    results = results.append(pd.DataFrame({'kF':kF
                                           ,'mean_P1':np.mean(results_kF['P1']),'std_P1':np.std(results_kF['P1'])
                                           ,'sigma_cm_x':np.std(results_kF['Pcm_x'])
                                           ,'sigma_cm_y':np.std(results_kF['Pcm_y'])
                                           ,'sigma_cm_z':np.std(results_kF['Pcm_z'])}
                                          ,index=[kF]))
    print 'done with kF=',kF,'MeV/c'
    
print 'done'
# Out:
# running kF= 200.0 MeV/c
# done with kF= 200.0 MeV/c
# running kF= 210.0 MeV/c
# done with kF= 210.0 MeV/c
# running kF= 220.0 MeV/c
# done with kF= 220.0 MeV/c
# running kF= 230.0 MeV/c
# done with kF= 230.0 MeV/c
# running kF= 240.0 MeV/c
# done with kF= 240.0 MeV/c
# running kF= 250.0 MeV/c
# done with kF= 250.0 MeV/c
# running kF= 260.0 MeV/c
# done with kF= 260.0 MeV/c
# running kF= 270.0 MeV/c
# done with kF= 270.0 MeV/c
# running kF= 280.0 MeV/c
# done with kF= 280.0 MeV/c
# running kF= 290.0 MeV/c
# done with kF= 290.0 MeV/c
# running kF= 300.0 MeV/c
# done with kF= 300.0 MeV/c
# done

# %% [markdown]
# ## The average momentum of a single particle as a function of $k_F$

# %%
fig=plt.figure(figsize=(9.708,6))
ax = fig.add_subplot(1,1,1)
# average momentum of a single particle calculated analytically 
plt.errorbar(x=results['kF'],xerr=0
             ,y=results['kF']*3/4,yerr=0
             ,fmt='o',markersize=10
             ,label=r'$\left< k \right> = \frac{\int_0^{k_F}k^3 dk}{\int_0^{k_F}k^2 dk} = \frac{3}{4}k_F$')
plt.errorbar(x=results['kF'],xerr=0
             ,y=results['mean_P1'],yerr=0*results['std_P1']
             ,fmt='o',markersize=10,label=None)
ymin = np.min(ax.get_ylim())
pars = np.polyfit(x=results['kF'],y=results['mean_P1'],deg=1)
sigma_MF_label=r'$\left<p^{MF}\right> \simeq %.2f \cdot k_F  %.2f$'%(pars[0],pars[1])
poly = np.poly1d(pars)
xpoly = np.linspace(200,300,100)
plt.plot(xpoly,poly(xpoly),'--',color='royalblue',linewidth=2,label=sigma_MF_label)
set_axes(ax,r'$k_F$ [MeV/c]',r'$\left<p^{MF}\right>$ [MeV/c]',do_add_grid=True)
leg=plt.legend(bbox_to_anchor=(1.,1.05),loc=2,fontsize=25)
plt.savefig('/Users/erezcohen/Desktop/Paverage_vs_kF.pdf', bbox_extra_artists=(leg,), bbox_inches='tight')

# %% [markdown]
# ## The resulting $\sigma_{c.m.}$ as a function of $k_F$

# %%
results['sigma_cm_average'] = (results['sigma_cm_x']+results['sigma_cm_y']+results['sigma_cm_z'])/3.
results['sigma_cm_std'] = np.sqrt((np.square(results['sigma_cm_x']-results['sigma_cm_average'])
                           +np.square(results['sigma_cm_y']-results['sigma_cm_average'])                          
                           +np.square(results['sigma_cm_z']-results['sigma_cm_average']))/3.)

# %%
fig=plt.figure(figsize=(19.416,12))

ax = fig.add_subplot(2,2,1)
for p,color,plabel in zip(['P1','P2'],['red','blue'],['first nucleon','second nucleon']):
    plt.hist(results_kF_dict[220][p],bins=linspace(0,220,35),histtype='step',linewidth=3,color=color);
    plt.plot([0,0],[0,0],linewidth=3,label=plabel,color=color)
set_axes(ax,r'nucleon momentum [MeV/c]','frequency [a.u.]',title='example: momentum generation in C'
         ,do_add_grid=True,do_add_legend=True,legend_loc='upper left')


ax = fig.add_subplot(2,2,2)
plot_2d_hist(180./np.pi*results_kF_dict[220]['P1_theta']
             ,180./np.pi*results_kF_dict[220]['P1_phi']
             ,bins=25#(linspace(0,180,25),linspace(0,360,25))
             ,ax=ax);
set_axes(ax,r'$\theta$ [deg.]',r'$\phi$ [deg.]',do_add_grid=True,title='direction of first nucleon')





ax = fig.add_subplot(2,2,3)
plt.errorbar(x=results['kF'],xerr=5,y=results['sigma_cm_average'],yerr=results['sigma_cm_std']
             ,fmt='o',markersize=10,label=None)
ymin = np.min(ax.get_ylim())
pars = np.polyfit(x=results['kF'],y=results['sigma_cm_average'],deg=1)
sigma_MF_label=r'$\left<\sigma_{c.m.}^{MF}\right> \simeq %.2f k_F %.2f$'%(pars[0],pars[1])
poly = np.poly1d(pars)
xpoly = np.linspace(200,300,100)
plt.plot(xpoly,poly(xpoly),'--',color='royalblue',linewidth=2,label=sigma_MF_label)

plt.plot([221,221],[ymin,poly(221)],'--'
         ,[250,250],[ymin,poly(250)],'--'
         ,[260,260],[ymin,poly(260)],'--'
         ,[275,275],[ymin,poly(275)],'--',color='black',label='Moniz C,Al,Fe,Pb')
set_axes(ax,r'$k_F$ [MeV/c]',r'$\sigma_{c.m.}^{MF}$ [MeV/c]',do_add_grid=True,do_add_legend=True,legend_loc='upper left')




ax = fig.add_subplot(2,2,4)
nominal_results = pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/final_results/nominal_results.csv')
nominal_results['A']=[12,27,56,208]
labels=dict({'$^{12}$C':(9,158), '$^{27}$Al':(21,178),'$^{56}$Fe':(45,185), '$^{208}$Pb':(120,178)})
for label in list(labels.keys()): ax.text(labels[label][0],labels[label][1],label,fontsize=35)
plot_data_assymetric( data=nominal_results,direction='t',ax=ax, label="This work"
                     , marker='o', markersize=20 , capthick=2, capsize=14 )
plt.errorbar(x=[12,27,56,208],xerr=0
             ,y=poly([221,250,260,275])
             ,yerr=[[5,5,5,5],[5,5,5,5]]
             ,fmt='s',markersize=10,label=sigma_MF_label)
set_axes(ax , 'A' , '$\sigma_{c.m.}$ [MeV/c]' ,xticks=[4,12,27,56,208],yticks=[100,125,150,175,200]
         ,xlim=(2.5,250),ylim=(79,205)
         ,do_add_grid=True,do_add_legend=True,legend_loc='lower left')
ax.set_xscale('log')


plt.tight_layout()
filename='/Users/erezcohen/Desktop/sigma_t_vs_kF.pdf'
plt.savefig(filename)
print 'saved',filename
# Out:
# saved /Users/erezcohen/Desktop/sigma_t_vs_kF.pdf

# %%
plt.hist(results['Pcm_y'],bins=linspace(-300,300,35));
sigma_y = np.std(results['Pcm_y'])
print sigma_y
# Out:
# 95.1120584642

# %%
plt.hist(results['P1_y'],bins=linspace(-200,200,35));
