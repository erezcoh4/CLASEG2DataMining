# %% [markdown]
# # internal note v 3.3 Aug-20, 2017

# %%
import sys ; sys.path.insert(0, '../')
from notebook_tools import *
import matplotlib.mlab as mlab
# %matplotlib inline

# %%
figures_path="/Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/"

# %% [markdown]
# # pp-SRC c.m. analysis

# %%
columns = ['Pmiss3Mag','pcmX','pcmY','pcmZ','rooWeight'] # ,'Mott','DipoleFF2'
data_allPmiss_noPrecFid , data300Pmiss600_noPrecFid = dict() , dict()
data_allPmiss_PrecFid , data300Pmiss600_PrecFid = dict() , dict()

for target in ['C12','Al27','Fe56','Pb208']:
    data_allPmiss_noPrecFid[target] = read_root( path+"/OrAnalysisTrees/AdjustedTrees/SRC_e2p_adjusted_300Pmiss600_%s_NoPrecFiducials.root"%target, columns=columns )
    data300Pmiss600_noPrecFid[target] = data_allPmiss_noPrecFid[target][data_allPmiss_noPrecFid[target]['Pmiss3Mag']<0.6]
#     data300Pmiss600_noPrecFid[target]['Mott*DipoleFF2']=data300Pmiss600_noPrecFid[target]['Mott']*data300Pmiss600_noPrecFid[target]['DipoleFF2']
    data_allPmiss_PrecFid[target] = read_root( path+"/OrAnalysisTrees/AdjustedTrees/SRC_e2p_adjusted_300Pmiss600_%s_PrecFiducials.root"%target, columns=columns )
    data300Pmiss600_PrecFid[target] = data_allPmiss_PrecFid[target][data_allPmiss_PrecFid[target]['Pmiss3Mag']<0.6]

# %%
cm_parameters = dict()
cm_parameters_with_correction = dict()
for Fiducials in ["PrecFiducials","NoPrecFiducials"]:
    cm_pars = pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/300Pmiss600/alltargets_'+Fiducials+'_dataCMparameters.csv')
    cm_pars['sigma_t'] = 0.5*(cm_pars['sigma_x_unweighted']+cm_pars['sigma_y_unweighted'])
    cm_pars['sigma_tErr'] = 0.5*np.sqrt( np.square(cm_pars['sigma_xErr_unweighted']) + np.square(cm_pars['sigma_yErr_unweighted']) )
#     cm_pars['sigma_t_weighted'] = 0.5*(cm_pars['sigma_x_weighted']+cm_pars['sigma_y_weighted'])
#     cm_pars['sigma_tErr_weighted'] = 1./np.sqrt( 1./np.square(cm_pars['sigma_xErr_weighted']) + 1./np.square(cm_pars['sigma_yErr_weighted']) )
    cm_parameters[Fiducials] = cm_pars
    cm_parameters_with_correction[Fiducials] = cm_pars

# %% [markdown]
# ## cm_parameters['PrecFiducials']

# %%
cm_parameters['PrecFiducials'][['sigma_x_unweighted','sigma_xErr_unweighted','sigma_y_unweighted','sigma_yErr_unweighted','sigma_z_unweighted','sigma_zErr_unweighted','chi2red_x_unweighted']]
# Out:
#    sigma_x_unweighted  sigma_xErr_unweighted  sigma_y_unweighted  \
# 0            0.158378               0.006865            0.161638
# 1            0.181341               0.013666            0.166910
# 2            0.178723               0.008388            0.185658
# 3            0.196040               0.020634            0.164304
#
#    sigma_yErr_unweighted  sigma_z_unweighted  sigma_zErr_unweighted  \
# 0               0.007007            0.147251               0.006384
# 1               0.012570            0.141058               0.010629
# 2               0.008706            0.150658               0.007069
# 3               0.017300            0.169545               0.017832
#
#    chi2red_x_unweighted
# 0              0.602767
# 1              1.058674
# 2              0.471936
# 3              0.847317

# %%
cm_parameters['PrecFiducials'][['mean_x_unweighted','mean_xErr_unweighted','mean_y_unweighted','mean_yErr_unweighted','mean_z_unweighted','mean_zErr_unweighted']]
# Out:
#    mean_x_unweighted  mean_xErr_unweighted  mean_y_unweighted  \
# 0          -0.026697              0.009711          -0.005837
# 1          -0.035170              0.019329           0.017157
# 2          -0.027254              0.011862          -0.009223
# 3          -0.024147              0.029217           0.016012
#
#    mean_yErr_unweighted  mean_z_unweighted  mean_zErr_unweighted
# 0              0.009910           0.106593              0.009028
# 1              0.017791           0.118663              0.015036
# 2              0.012322           0.149765              0.009999
# 3              0.024489           0.177513              0.025269

# %%
cm_pars = cm_parameters['PrecFiducials']

for target,name in zip(['C12','Al27','Fe56','Pb208']
                       ,['$^{12}$C','$^{27}$Al','$^{56}$Fe','$^{208}$Pb']):
    weight_name = ''
    fig=plt.figure(figsize=(18,6))
    for i,(cm_pars_dir,direction,label) in enumerate(zip(['x','y','z']
                                                         ,['X','Y','Z']                                             
                                                         ,['x','y','p_{miss}'])):
        ax=fig.add_subplot(1,3,i+1)
        x = data300Pmiss600_PrecFid[target]['pcm'+direction]
        xmin = -0.6 if i<2 else -0.4       
        xmax = 0.6 if i<2 else 0.8
        bins=np.linspace(xmin,xmax,16)

        if weight_name != '':
            weights = 1./data300Pmiss600[target][weight_name]
        else: weights=None
        h,bins,_=plt.hist( x,  weights=weights , bins=bins)
        NormFact = len(x)*(bins[1]-bins[0])
        cm_pars_target = cm_pars[cm_pars['target']==name]
        mean = float(cm_pars_target['mean_'+cm_pars_dir+'_unweighted'])
        mean_err = float(cm_pars_target['mean_'+cm_pars_dir+'Err_unweighted'])
        sigma = float(cm_pars_target['sigma_'+cm_pars_dir+'_unweighted'])
        sigma_err = float(cm_pars_target['sigma_'+cm_pars_dir+'Err_unweighted'])
        chi2red = float(cm_pars_target['chi2red_'+cm_pars_dir+'_unweighted'])


        set_axes(ax,'$p_{cm}^{%s}$ [GeV/c]'%label, xticks=np.linspace(xmin,xmax,4))
        x_v = np.linspace(xmin,xmax,100)
        plt.plot( x_v , NormFact*mlab.normpdf(x_v, mean, sigma),'--',color='red',linewidth=2.5)
        ax.set_xlim(xmin,xmax)
        ax.set_ylim(0,1.02*np.max(h))

        xtext = xmin+0.02*(xmax-xmin) 
        if direction=='X': 
            plt.text( xtext, 0.85*np.max(ax.get_ylim()), name , fontsize=45)
        # parametrs on text
        if target!='C12' and direction=='X':
            xtext = xmax-0.37*(xmax-xmin) 
        plt.text( xtext, 0.6*np.max(ax.get_ylim()), '$\\mu:%.3f(%.0f)$\n$\\sigma:%.3f(%.0f)$\n$\chi^{2}_{red}=%.2f$'%(mean,1000*mean_err,sigma,1000*sigma_err,chi2red), color='red' , fontsize=20)

        
    plt.tight_layout()
    outfilename = figures_path+'MeasuredDistributions/MeasuredDistribution'+target+'.pdf' 
    print 'saved ' + outfilename
    plt.savefig(outfilename)
# Out:
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/MeasuredDistributions/MeasuredDistributionC12.pdf
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/MeasuredDistributions/MeasuredDistributionAl27.pdf
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/MeasuredDistributions/MeasuredDistributionFe56.pdf
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/MeasuredDistributions/MeasuredDistributionPb208.pdf

# %% [markdown]
# for target,name in zip(['C12','Al27','Fe56','Pb208']
#                        ,['$^{12}$C','$^{27}$Al','$^{56}$Fe','$^{208}$Pb']):
#     fig=plt.figure(figsize=(12,8))
#     ax=fig.add_subplot(1,1,1)
#     x = data300Pmiss600_PrecFid[target]['Pmiss3Mag']
#     h,bins,_=plt.hist( x,  bins=np.linspace(0.3,0.6,25))
#     set_axes(ax,'$p_{miss}^{%s}$ [GeV/c]'%label, xticks=np.linspace(0.3,0.6,4))
#     x_v = np.linspace(xmin,xmax,100)
#     ax.set_ylim(0,1.02*np.max(h))
#     plt.text( 0.35, 0.8*np.max(ax.get_ylim()), name , fontsize=45)
#     outfilename = figures_path+'MeasuredDistributions/Pmiss_'+target+'.pdf'
#     print 'saved ' + outfilename
#     plt.savefig(outfilename)

# %% [markdown]
# fig = plt.figure(figsize=(16,8))
# ax = fig.add_subplot(1,1,1)
# ax.errorbar(x=cm_pars['A'],y=cm_pars['mean_x_unweighted'],yerr=cm_pars['mean_xErr_unweighted'],fmt='s',color='red',label='$x-direction$')
# ax.errorbar(x=cm_pars['A']-2,y=cm_pars['mean_y_unweighted'],yerr=cm_pars['mean_yErr_unweighted'],fmt='s',color='black',label='$y-direction$')
#
# ax.errorbar(x=cm_pars['A']-2,y=cm_pars['mean_z_unweighted'],yerr=cm_pars['mean_zErr_unweighted'],fmt='s',color='blue',label='$\\vec{p}_{miss}-direction$')
# set_axes(ax,'A','$\\mu_{c.m.}$ [GeV/c]')
# ax.xaxis.set_ticks([12,27,56,208])
# ax.grid(linestyle='--',alpha=0.8)
# ax.legend(fontsize=25,loc='upper center')
# outfilename = figures_path + 'mean_cm_Adependence.pdf'
# plt.savefig(outfilename)
#
# fig = plt.figure(figsize=(16,8))
# ax = fig.add_subplot(1,1,1)
# ax.errorbar(x=cm_pars['A'],y=cm_pars['sigma_x_unweighted'],yerr=cm_pars['sigma_xErr_unweighted'],fmt='s',color='red',label='$x-direction$')
# ax.errorbar(x=cm_pars['A']-2,y=cm_pars['sigma_y_unweighted'],yerr=cm_pars['sigma_yErr_unweighted'],fmt='s',color='black',label='$y-direction$')
# ax.errorbar(x=cm_pars['A']+2,y=cm_pars['sigma_z_unweighted'],yerr=cm_pars['sigma_zErr_unweighted'],fmt='s',color='blue',label='$\\vec{p}_{miss}-direction$')
# set_axes(ax,'A','$\\sigma_{c.m.}$ [GeV/c]')
# ax.xaxis.set_ticks([12,27,56,208]);ax.yaxis.set_ticks([0.13,0.15,0.17,0.19,0.21]);
# ax.grid(linestyle='--',alpha=0.8)
# ax.legend(fontsize=25,loc='upper center')
# outfilename = figures_path + 'sigma_cm_Adependence.pdf'
# plt.savefig(outfilename)

# %% [markdown]
# # the simulation assumes a Gaussian distribution around the meas. values with 5 standard deviations as width

# %%
fig = plt.figure(figsize=(16,12))
ax = fig.add_subplot(2,1,1)
ax.errorbar(x=cm_pars['A'],y=cm_pars['mean_z_unweighted'],yerr=cm_pars['mean_zErr_unweighted'],fmt='s'
            ,color='blue',label='measured $\\mu_{\\vec{p}_{miss}}$')
ax.fill_between(cm_pars['A']
                ,cm_pars['mean_z_unweighted']-5*cm_pars['mean_zErr_unweighted']
                ,cm_pars['mean_z_unweighted']+5*cm_pars['mean_zErr_unweighted']
                ,color='royalblue',alpha=0.2,label='5$\\sigma$ around measured value')
plt.plot(cm_pars['A'],cm_pars['mean_z_unweighted']-5*cm_pars['mean_zErr_unweighted'],'-',linewidth=3,color='royalblue')
plt.plot(cm_pars['A'],cm_pars['mean_z_unweighted']+5*cm_pars['mean_zErr_unweighted'],'-',linewidth=3,color='royalblue')

set_axes(ax,'','$\\mu_{miss}$ [GeV/c]')
ax.xaxis.set_ticks([12,27,56,208]);ax.yaxis.set_ticks([0.05,0.15,0.25,0.35]);
ax.grid(linestyle='--',alpha=0.8)
ax.legend(fontsize=25,loc='upper left')
ax.xaxis.set_major_formatter(NullFormatter())


ax = fig.add_subplot(2,1,2)
ax.errorbar(x=cm_pars['A'],y=cm_pars['sigma_z_unweighted'],yerr=cm_pars['sigma_zErr_unweighted'],fmt='s'
            ,color='blue',label='measured $\\sigma_{\\vec{p}_{miss}}$')
ax.fill_between(cm_pars['A']
                ,cm_pars['sigma_z_unweighted']-5*cm_pars['sigma_zErr_unweighted']
                ,cm_pars['sigma_z_unweighted']+5*cm_pars['sigma_zErr_unweighted']
                ,color='royalblue',alpha=0.2,label='5$\\sigma$ around measured value')
plt.plot(cm_pars['A'],cm_pars['sigma_z_unweighted']-5*cm_pars['sigma_zErr_unweighted'],'-',linewidth=3,color='royalblue')
plt.plot(cm_pars['A'],cm_pars['sigma_z_unweighted']+5*cm_pars['sigma_zErr_unweighted'],'-',linewidth=3,color='royalblue')

set_axes(ax,'A','$\\sigma_{c.m.}$ [GeV/c]')
ax.xaxis.set_ticks([12,27,56,208]);ax.yaxis.set_ticks([0.08,0.12,0.16,0.20,0.24]);
ax.grid(linestyle='--',alpha=0.8)
ax.legend(fontsize=25,loc='upper left')

plt.tight_layout()
outfilename = figures_path + 'mean_sigma_z_Adependence_band_5std_around_measured.pdf'
print 'saved',outfilename
plt.savefig(outfilename)
# Out:
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/mean_sigma_z_Adependence_band_5std_around_measured.pdf

# %%
simulation_results = dict()
test_names = []
for Fiducials in ["PrecFiducials","NoPrecFiducials"]:
    for target in ['C','Al','Fe','Pb']:#{
            test_name = "sims_300Pmiss600_"+target+"_"+Fiducials
            test_names.append(test_name)    
            simulation_results[test_name] = pd.read_csv("/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/results_300Pmiss600/"+test_name+'.csv')
            simulation_results[test_name].fillna(-1,inplace=True)
            print len(simulation_results[test_name]),'events in ',test_name
# Out:
# 12150 events in  sims_300Pmiss600_C_PrecFiducials
# 12046 events in  sims_300Pmiss600_Al_PrecFiducials
# 12000 events in  sims_300Pmiss600_Fe_PrecFiducials
# 10675 events in  sims_300Pmiss600_Pb_PrecFiducials
# 12150 events in  sims_300Pmiss600_C_NoPrecFiducials
# 12150 events in  sims_300Pmiss600_Al_NoPrecFiducials
# 12150 events in  sims_300Pmiss600_Fe_NoPrecFiducials
# 9809 events in  sims_300Pmiss600_Pb_NoPrecFiducials

# %%
Fiducials = "PrecFiducials"
for extraname in ["_mean75MeVc_sigma50MeVc","_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured"]:
    for target in ['C','Al','Fe','Pb']:#{
        test_name = "sims_300Pmiss600_"+target+"_"+Fiducials+extraname
        test_names.append(test_name)    
        simulation_results[test_name] = pd.read_csv("/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/results_300Pmiss600/"+test_name+'.csv')
        simulation_results[test_name].fillna(-1,inplace=True)
        print len(simulation_results[test_name]),'events in ',test_name
# Out:
# 12150 events in  sims_300Pmiss600_C_PrecFiducials_mean75MeVc_sigma50MeVc
# 12150 events in  sims_300Pmiss600_Al_PrecFiducials_mean75MeVc_sigma50MeVc
# 12150 events in  sims_300Pmiss600_Fe_PrecFiducials_mean75MeVc_sigma50MeVc
# 12150 events in  sims_300Pmiss600_Pb_PrecFiducials_mean75MeVc_sigma50MeVc
# 12150 events in  sims_300Pmiss600_C_PrecFiducials_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# 12150 events in  sims_300Pmiss600_Al_PrecFiducials_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# 12150 events in  sims_300Pmiss600_Fe_PrecFiducials_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# 12150 events in  sims_300Pmiss600_Pb_PrecFiducials_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured

# %%
def find_x_poly(poly,y0,xmin=0,xmax=0.3):
    p = np.poly1d(poly)
    roots = (p - y0).roots
    for root in roots:
        if xmin<root and root<xmax:
            x_poly = root
    return x_poly

# %%
def plot_cm_direction(simulations_results=None
                      ,Fiducials='PrecFiducials'
                      ,extraname=""
                      ,ax=None,A=12
                      ,poly_degree=3
                      ,confidence_interval = 0.68
                      ,direction='x',colors=['blue','royalblue'],s=50
                      ,debug=0):

    gen,rec = simulations_results['gen_Sigma_t'],simulations_results['rec_sigma_'+direction]
    plt.scatter(gen,rec,color=colors[1],label='generated vs. reconstructed',s=s)
    if debug:  print "plt.scatter()"
    # fit a polynomial of order 2
    popt,cov = np.polyfit( gen,rec , poly_degree , cov=True)
    perr = np.sqrt(np.diag(cov))
    if debug: print "popt:",popt,"\nperr:",perr
    
    x = np.linspace(np.min(ax.get_xlim()),np.max(ax.get_xlim()),1000)
    poly = np.poly1d(popt)
    ax.plot(x,poly(x),'-',color='black',linewidth=2,label='best fit')    
    
    # Convert to percentile point of the normal distribution [https://en.wikipedia.org/wiki/Standard_score]
    pp = (1. + confidence_interval) / 2.
    # Convert to number of standard deviations.
    nstd = stats.norm.ppf(pp)
    
    # Add nstd standard deviations to parameters to obtain the upper confidence interval
    poly_up = np.poly1d(popt + nstd * perr)
    ax.plot(x,poly_up(x),'-',color='gray',linewidth=2)
    poly_dw = np.poly1d(popt - nstd * perr)
    ax.plot(x,poly_dw(x),'-',color='gray',linewidth=2)

    cm_pars_target = cm_pars[cm_pars['A']==A]
    index = cm_pars[cm_pars['A']==A].index
    # reconstructed \sigma in data
    sigma_meas, sigma_meas_err = float(cm_pars_target['sigma_'+direction+'_unweighted']), float(cm_pars_target['sigma_'+direction+'Err_unweighted'])
    y =  np.ones(len(x)) * sigma_meas
    yErr =  np.ones(len(x)) * sigma_meas_err

    # corrected value
    # --- - - -- -- - -- - -- -- - -- -- -- - -- --- 
    corr_value =  find_x_poly(poly , sigma_meas)
    plt.plot( np.linspace(np.min(ax.get_xlim()),corr_value,1000) , y , color=colors[1],label='measured: $%.3f\\pm%.3f$'%(sigma_meas, sigma_meas_err))
    # --- - - -- -- - -- - -- -- - -- -- -- - -- --- 

    # only statistical uncertainty
    # --- - - -- -- - -- - -- -- - -- -- -- - -- --- 
    x_poly_up = find_x_poly(poly,sigma_meas+sigma_meas_err)
    x_poly_down = find_x_poly(poly,sigma_meas-sigma_meas_err)
    corr_value_err_statistical = x_poly_up - corr_value
    plt.plot( [x_poly_up,x_poly_up] , [np.min(ax.get_ylim()),sigma_meas+sigma_meas_err] , color='black' ,linestyle='--')
    plt.plot( [x_poly_down,x_poly_down] , [np.min(ax.get_ylim()),sigma_meas-sigma_meas_err] , color='black' ,linestyle='--' )
    # --- - - -- -- - -- - -- -- - -- -- -- - -- --- 

    # total uncertainty
    # --- - - -- -- - -- - -- -- - -- -- -- - -- --- 
    x_poly_up = find_x_poly(poly_dw,sigma_meas+sigma_meas_err)
    x_poly_down = find_x_poly(poly_up,sigma_meas-sigma_meas_err)
    corr_value_err_total = x_poly_up - corr_value

    if debug:  print "plt.plot( np.linspace(np.min(ax.get_xlim()),corr_value,1000)..."   
    # projection of the measured uncertainties
    plt.plot( np.linspace(np.min(ax.get_xlim()),x_poly_up,1000) , y+yErr , color=colors[0],linestyle='-',alpha=0.35)
    plt.plot( np.linspace(np.min(ax.get_xlim()),x_poly_down,1000) , y-yErr , color=colors[0],linestyle='-',alpha=0.35)

    # projection of the total uncertainties
    plt.plot( [x_poly_up,x_poly_up] , [np.min(ax.get_ylim()),sigma_meas+sigma_meas_err] , color='grey' ,linestyle='-')
    plt.plot( [x_poly_down,x_poly_down] , [np.min(ax.get_ylim()),sigma_meas-sigma_meas_err] , color='grey' ,linestyle='-' )
    # --- - - -- -- - -- - -- -- - -- -- -- - -- --- 
    print "plugging",'sigma_'+direction+'_corrected'+extraname
    
    # corrected value
    # --- - - -- -- - -- - -- -- - -- -- -- - -- --- 
    err_stat = corr_value_err_statistical
    err_sys = np.sqrt( np.square(corr_value_err_total) - np.square(err_stat) )
    plt.plot( [corr_value,corr_value] , [np.min(ax.get_ylim()),sigma_meas] , color=colors[0]
             ,label='corrected: $%.3f(%.0f_{stat.})(%.0f_{sys.})$'%(corr_value, 1000*err_stat, 1000*err_sys))
    # --- - - -- -- - -- - -- -- - -- -- -- - -- --- 


    
    
    cm_parameters_with_correction[Fiducials].set_value(index,'sigma_'+direction+'_corrected'+extraname,corr_value)
    cm_parameters_with_correction[Fiducials].set_value(index,'sigma_'+direction+'_corrected_err'+extraname,corr_value_err_total)
    
    cm_parameters_with_correction[Fiducials].set_value(index,'sigma_'+direction+'_corrected_err_statistical'+extraname,corr_value_err_statistical)
    cm_parameters_with_correction[Fiducials].set_value(index,'sigma_'+direction+'_corrected_err_total'+extraname,corr_value_err_total)
    
    set_axes(ax,'gen. $\\sigma$ [GeV/c]','rec. $\\sigma_'+direction+'$ [GeV/c]'    
             , xticks=[0,0.05,0.1,0.15,0.2,0.25,0.3] , yticks=[0,0.05,0.1,0.15,0.2,0.25,0.3] , do_add_grid=True 
             ,title = cm_pars_target['target'].to_string(index=False) + ', $'+direction+'-direction$ ('+Fiducials+')')

    ax.legend(loc='upper left',fontsize=20,scatterpoints=3)
    ax.set_xlim(0,0.3);ax.set_ylim(0,0.3);
    return corr_value, corr_value_err_total

# %%
poly_degree = 3 # fit polynomial degree
confidence_interval = 0.68 # band around fit

for Fiducials in ["PrecFiducials"]:#,"NoPrecFiducials"]: 
    for A,target in zip([208]#[12,27,56,208]
                        ,['Pb']#['C','Al','Fe','Pb']
                       ):#{
        test_name = "sims_300Pmiss600_"+target+"_"+Fiducials
        simulations_results=simulation_results[test_name]
        good_results = simulations_results[(simulations_results['rec_sigma_x']>0)&(simulations_results['rec_sigma_y']>0)]

        fig=plt.figure(figsize=(20,8))
    
        ax=fig.add_subplot(1,2,1)    
        corr_sigma_x, corr_sigma_x_err = plot_cm_direction(simulations_results=good_results
                                                           ,Fiducials=Fiducials                                                           
                                                           ,ax=ax,s=10                                                           
                                                           ,poly_degree=poly_degree,confidence_interval=confidence_interval                                                           
                                                           ,A=A,direction='x'                                                           
                                                           ,colors=['blue','royalblue']);

        ax=fig.add_subplot(1,2,2)    
        corr_sigma_y, corr_sigma_y_err = plot_cm_direction(simulations_results=good_results
                                                           ,Fiducials=Fiducials                                                                                                                                                                                 
                                                           ,ax=ax,s=10                                                           
                                                           ,poly_degree=poly_degree,confidence_interval=confidence_interval                                                           
                                                           ,A=A,direction='y'                                                           
                                                           ,colors=['red','salmon']);                        
    
        plt.tight_layout()   
        outfilename=figures_path+'sigma_t_corr_'+target+'_bands'+'_'+Fiducials+'.pdf'
        print 'saved',outfilename
        plt.savefig(outfilename)
# Out:
# plugging sigma_x_corrected
# plugging sigma_y_corrected
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_Pb_bands_PrecFiducials.pdf

# %%
poly_degree = 3 # fit polynomial degree
confidence_interval = 0.68 # band around fit
Fiducials = "PrecFiducials"
for extraname in ["_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured","_mean75MeVc_sigma50MeVc"]:

    for A,target in zip([12,27,56,208]
                        ,['C','Al','Fe','Pb']
                       ):#{
        test_name = "sims_300Pmiss600_"+target+"_"+Fiducials+extraname
        simulations_results=simulation_results[test_name]
        good_results = simulations_results[(simulations_results['rec_sigma_x']>0)                                       
                                           &(simulations_results['rec_sigma_y']>0)
#                                            &(simulations_results['rec_mean_x']<0.1)
#                                            &(simulations_results['rec_mean_y']<0.1)
                                          ]
        fig=plt.figure(figsize=(20,8))
    
        ax=fig.add_subplot(1,2,1)    
        corr_sigma_x, corr_sigma_x_err = plot_cm_direction(simulations_results=good_results
                                                           ,Fiducials=Fiducials
                                                           ,extraname=extraname                                                                                                                
                                                           ,ax=ax,s=10                                                           
                                                           ,poly_degree=poly_degree,confidence_interval=confidence_interval                                                           
                                                           ,A=A,direction='x'                                                           
                                                           ,colors=['blue','royalblue']);

        ax=fig.add_subplot(1,2,2)    
        corr_sigma_y, corr_sigma_y_err = plot_cm_direction(simulations_results=good_results
                                                           ,Fiducials=Fiducials  
                                                           ,extraname=extraname
                                                           ,ax=ax,s=10                                                           
                                                           ,poly_degree=poly_degree,confidence_interval=confidence_interval                                                           
                                                           ,A=A,direction='y'                                                           
                                                           ,colors=['red','salmon']);                        
    
        plt.tight_layout()   
        outfilename=figures_path+'sigma_t_corr_'+target+'_bands'+'_'+Fiducials+extraname+".pdf"
        print 'saved',outfilename
        plt.savefig(outfilename)
# Out:
# plugging sigma_x_corrected_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# plugging sigma_y_corrected_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_C_bands_PrecFiducials_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured.pdf
# plugging sigma_x_corrected_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# plugging sigma_y_corrected_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_Al_bands_PrecFiducials_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured.pdf
# plugging sigma_x_corrected_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# plugging sigma_y_corrected_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_Fe_bands_PrecFiducials_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured.pdf
# plugging sigma_x_corrected_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# plugging sigma_y_corrected_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_Pb_bands_PrecFiducials_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured.pdf
# plugging sigma_x_corrected_mean75MeVc_sigma50MeVc
# plugging sigma_y_corrected_mean75MeVc_sigma50MeVc
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_C_bands_PrecFiducials_mean75MeVc_sigma50MeVc.pdf
# plugging sigma_x_corrected_mean75MeVc_sigma50MeVc
# plugging sigma_y_corrected_mean75MeVc_sigma50MeVc
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_Al_bands_PrecFiducials_mean75MeVc_sigma50MeVc.pdf
# plugging sigma_x_corrected_mean75MeVc_sigma50MeVc
# plugging sigma_y_corrected_mean75MeVc_sigma50MeVc
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_Fe_bands_PrecFiducials_mean75MeVc_sigma50MeVc.pdf
# plugging sigma_x_corrected_mean75MeVc_sigma50MeVc
# plugging sigma_y_corrected_mean75MeVc_sigma50MeVc
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/sigma_t_corr_Pb_bands_PrecFiducials_mean75MeVc_sigma50MeVc.pdf

# %%
# target='Pb'
# A = 12 if target=='C' else (27 if target=='Al' else (56 if target=='Fe' else 208))
# fig=plt.figure(figsize=(18,16))
# for i,(sample,title) in enumerate(zip([
#         simulation_results['sims_300Pmiss600_'+target+'_PrecFiducials'],
# #                pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/results_300Pmiss600/sims_300Pmiss600_NoPrecFiducials_'+target+'_11700.csv'),
#                pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/simulation_300Pmiss600/NoPrecFiducials_'+target+'.csv'),
# #                pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/simulation_300Pmiss600/simulation_300Pmiss600_'+target+'_runs_0_1000runs_results.csv'),
#                pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/simulation_300Pmiss600/simulation_300Pmiss600_'+target+'_runs_0_1000runs_results.csv')
#     ],['previous PrecFiducials',
#        'Helion simulations',
# #        'previous iMac simulations running',
#        'ongoing iMac simulations running'
#       ])):
#     print 'len(sample):',len(sample)
#     ax=fig.add_subplot(2,2,i+1)
#     sample=sample[(sample['rec_sigma_x']>0)&(sample['rec_sigma_y']>0)]
#     green_sample=sample[np.abs(sample['rec_mean_x'])<0.02]
#     red_sample=sample[(sample['rec_mean_x']>0.02)&(sample['rec_mean_x']<0.1)]
#     blue_sample=sample[(sample['rec_mean_x']<-0.02)]
#     orange_sample=sample[(sample['rec_mean_y']<0)]

# #     (sample['rec_mean_y']>-1)&(sample['rec_mean_x']>-1)&(sample['rec_mean_z']>-1)&              
# #         &(sample['rec_mean_y']<0.1)&(sample['rec_mean_z']<0.1)& (sample['gen_MeanX']>-1)&(sample['gen_MeanY']>-1)&(sample['gen_MeanZ']>-1)#&            (sample['gen_SigmaZ']>0)
# #     ]
#     for sam,color in zip([sample]#,red_sample,blue_sample,green_sample,orange_sample]
#                          ,['black','red','royalblue','green','orange']):
#         ax.scatter(sam['gen_Sigma_t'],sam['rec_sigma_x'],color=color);    ax.set_xlim(0,0.3);ax.set_ylim(0.0,0.4);     
# #         ax.scatter(sam['rec_mean_y'],sam['rec_sigma_x'],color=color);    ax.set_xlim(-0.3,0.3);    
# #         ax.scatter(sam['gen_MeanX'],sam['rec_sigma_x'],color=color);    ax.set_xlim(-0.27,0.4);
# #         ax.scatter(sam['rec_mean_x'],sam['rec_mean_y'],color=color);    ax.set_xlim(-0.2,0.2);ax.set_ylim(-0.06,0.06); 
#     # print "mean(sam['rec_mean_x']):",np.mean(sam['rec_mean_x'])
#     if i<=30: plot_cm_direction(simulations_results=sample ,Fiducials='NoPrecFiducials' ,ax=ax,A=A ,poly_degree=3 ,confidence_interval = 0.95)
#     ax.set_title(title,fontsize=20)
#     set_axes(ax,'rec mean(x)','rec mean(y)' if i==0 else '',do_add_grid=True,xticks=[-0.15,-0.05,0.05,0.15])
# plt.tight_layout()

target='Pb'
fig=plt.figure(figsize=(12,8))
sample = pd.concat([pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/results_300Pmiss600/sims_300Pmiss600_'+target+'_PrecFiducials.csv')])
sam = sample[(sample['rec_sigma_x']>0)&(sample['rec_sigma_y']>0)]
plt.scatter(sam['gen_Sigma_t'],sam['rec_sigma_x'],color='black',s=5);    ax.set_xlim(0,0.3);ax.set_ylim(0.0,0.4);     
plt.scatter(sam['gen_Sigma_t'],sam['rec_sigma_x'],color='black',s=5);    ax.set_xlim(0,0.3);ax.set_ylim(0.0,0.4);

# %%
for Fiducials in ['NoPrecFiducials','PrecFiducials']:
    sample = cm_parameters_with_correction[Fiducials]
    sample['sigma_x_final'] = sample['sigma_x_corrected']
    sample['sigma_x_final_Err'] = sample['sigma_x_corrected_err']
    sample['sigma_y_final'] = sample['sigma_y_corrected']
    sample['sigma_y_final_Err'] = sample['sigma_y_corrected_err']
    sample['sigma_t_corrected'] = 0.5*(sample['sigma_x_corrected']+sample['sigma_y_corrected'])
    sample['sigma_t_corrected_Err'] = 0.5*np.sqrt(np.square(sample['sigma_x_corrected_err'])+np.square(sample['sigma_y_corrected_err']))
    sample['sigma_t_corrected_Err_stat'] = 0.5*np.sqrt(np.square(sample['sigma_x_corrected_err_statistical'])+np.square(sample['sigma_y_corrected_err_statistical']))
    sample['sigma_t_corrected_Err_sys'] = np.sqrt(np.square(sample['sigma_t_final_Err'])-np.square(sample['sigma_t_final_Err_stat']))
    # quadratically subtract 20 +/- 2 MeV/c to account for the c.m. measurement resolution
    sample['sigma_t_final'] = np.sqrt( np.square(sample['sigma_t_corrected']) - np.square(0.02))
    sample['sigma_t_final_Err'] = np.sqrt( np.square(sample['sigma_t_corrected_Err']) + np.square(0.002))
    sample['sigma_t_final_Err_stat'] = np.sqrt( np.square(sample['sigma_t_corrected_Err_stat']) + np.square(0.002) )
    sample['sigma_t_final_Err_sys'] = np.sqrt( np.square(sample['sigma_t_corrected_Err_sys']) + np.square(0.002) )




Fiducials = "PrecFiducials"
for extraname in ["_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured","_mean75MeVc_sigma50MeVc"]:
    sample['sigma_x'+extraname+'_final'] = sample['sigma_x_corrected'+extraname]
    sample['sigma_x'+extraname+'_final_Err'] = sample['sigma_x_corrected_err'+extraname]
    sample['sigma_y'+extraname+'_final'] = sample['sigma_y_corrected'+extraname]
    sample['sigma_y'+extraname+'_final_Err'] = sample['sigma_y_corrected_err'+extraname]
    sample['sigma_t'+extraname+'_corrected'] = 0.5*(sample['sigma_x_corrected'+extraname]+sample['sigma_y_corrected'+extraname])
    sample['sigma_t'+extraname+'_corrected_Err'] = 0.5*np.sqrt(np.square(sample['sigma_x_corrected_err'+extraname])+np.square(sample['sigma_y_corrected_err'+extraname]))    
    # quadratically subtract 20 +/- 2 MeV/c to account for the c.m. measurement resolution
    sample['sigma_t'+extraname+'_final'] = np.sqrt( np.square(sample['sigma_t'+extraname+'_corrected']) - np.square(0.02))
    sample['sigma_t'+extraname+'_final_Err'] = np.sqrt(np.square(sample['sigma_t'+extraname+'_corrected_Err'])+np.square(0.002))

# %%
cm_parameters_with_correction['PrecFiducials'][['sigma_t','sigma_tErr','sigma_t_final','sigma_t_final_Err','sigma_t_final_Err_sys','sigma_t_final_Err_stat']]
# Out:
#     sigma_t  sigma_tErr  sigma_t_final  sigma_t_final_Err  \
# 0  0.160008    0.004905       0.143341           0.006081
# 1  0.174126    0.009284       0.154069           0.011652
# 2  0.182190    0.006045       0.159073           0.007604
# 3  0.180172    0.013463       0.152367           0.019700
#
#    sigma_t_final_Err_sys  sigma_t_final_Err_stat
# 0               0.004345                0.004701
# 1               0.008357                0.008363
# 2               0.005576                0.005542
# 3               0.015953                0.011729

# %%
cm_parameters_with_correction['PrecFiducials']
# Out:
#    Nevts  chi2red_x_unweighted  chi2red_y_unweighted  chi2red_z_unweighted  \
# 0    266              0.602767              0.407306              2.139232
# 1     88              1.058674              0.542381              0.460758
# 2    227              0.471936              0.458693              1.598486
# 3     45              0.847317              0.596230              0.395723
#
#    mean_xErr_unweighted  mean_xErr_weighted  mean_x_unweighted  \
# 0              0.009711            0.024008          -0.026697
# 1              0.019329            0.020803          -0.035170
# 2              0.011862            0.033590          -0.027254
# 3              0.029217            0.050136          -0.024147
#
#    mean_x_weighted  mean_yErr_unweighted  mean_yErr_weighted  \
# 0         0.004220              0.009910            0.019150
# 1        -0.006808              0.017791            0.024075
# 2        -0.008921              0.012322            0.030910
# 3        -0.032452              0.024489            0.040063
#
#                      ...                     \
# 0                    ...
# 1                    ...
# 2                    ...
# 3                    ...
#
#    sigma_y_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured_final  \
# 0                                           0.148324
# 1                                           0.152905
# 2                                           0.170125
# 3                                           0.151072
#
#    sigma_y_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured_final_Err  \
# 0                                           0.008594
# 1                                           0.014683
# 2                                           0.011248
# 3                                           0.019597
#
#    sigma_t_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured_final  \
# 0                                           0.146113
# 1                                           0.158799
# 2                                           0.166419
# 3                                           0.165020
#
#    sigma_t_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured_final_Err  \
# 0                                           0.005997
# 1                                           0.011051
# 2                                           0.007754
# 3                                           0.016127
#
#    sigma_x_mean75MeVc_sigma50MeVc_final  \
# 0                              0.141698
# 1                              0.161099
# 2                              0.156015
# 3                              0.169175
#
#    sigma_x_mean75MeVc_sigma50MeVc_final_Err  \
# 0                                  0.009553
# 1                                  0.017295
# 2                                  0.011906
# 3                                  0.024121
#
#    sigma_y_mean75MeVc_sigma50MeVc_final  \
# 0                              0.146030
# 1                              0.149949
# 2                              0.162851
# 3                              0.143964
#
#    sigma_y_mean75MeVc_sigma50MeVc_final_Err  \
# 0                                  0.009859
# 1                                  0.015345
# 2                                  0.012593
# 3                                  0.018444
#
#    sigma_t_mean75MeVc_sigma50MeVc_final  \
# 0                              0.143864
# 1                              0.155524
# 2                              0.159433
# 3                              0.156569
#
#    sigma_t_mean75MeVc_sigma50MeVc_final_Err
# 0                                  0.006864
# 1                                  0.011561
# 2                                  0.008665
# 3                                  0.015182
#
# [4 rows x 79 columns]

# %% [markdown]
# # add calculations...

# %%
ColleCalc = pd.DataFrame({'A':[4,12 , 27 , 56 , 208],
                        'allpairs':[110,141,146,147.5,145.5],# average of HO and WS
                        'nl00':[110,157,166,173.,177.5]},# average of HO and WS
                         index = ['$^{4}$He','$^{12}$C','$^{27}$Al','$^{56}$Fe','$^{208}$Pb'])
CiofiCalc = pd.DataFrame({'A':[4 , 12 , 40 , 56 , 208], # 3 , 
                        's_t':[90 , 138.6174 , 142.6555 , 132.5117 , 151.3311]}, # 0.0724
                         index = ['$^{4}$He','$^{12}$C','$^{40}$Ca','$^{56}$Fe','$^{208}$Pb']) # '$^{3}$He',
MonizCalc = pd.DataFrame({'A':[12 , 40 , 208],
                        '3kF/4':[165.8 , 188.3 , 198.8]},
                         index = ['$^{12}$C','$^{40}$Ca','$^{208}$Pb'])

BNL_Data = pd.DataFrame({'A':[12],'sigma_t_final':[0.143],'sigma_t_final_Err':[0.017]},index = ['$^{12}$C'])
HallA_Data = pd.DataFrame({'A':[12],'sigma_t_final':[0.136],'sigma_t_final_Err':[0.020]},index = ['$^{12}$C'])
Korover_Data = pd.DataFrame({'A':[4],'sigma_t_final':[0.100],'sigma_t_final_Err':[0.020]},index = ['$^{4}$He'])

WI_Data = pd.DataFrame({'A':[ 12 , 27 , 56 , 208], 
                        'sigma_t_final':[0.158 , 0.156 , 0.181 , 0.174], 
                        'sigma_t_final_Err':[0.012 , 0.019 , 0.011 , 0.016]}, 
                         index = ['$^{12}$C','$^{27}$Al','$^{56}$Fe','$^{208}$Pb'])

# %%
from scipy.interpolate import interp1d, Akima1DInterpolator,BarycentricInterpolator,splprep

def plot_data(data , ax=None, direction='t', Ashift=0, fmt='o', marker='^',color='red',
                       markersize=15, linewidth=4, 
                       vary=None , varyerr=None , label=None , facecolors=None ):
    ax.errorbar((data['A']+Ashift), 
                y=1000*data['sigma_'+direction+'_final'],
                yerr=1000*data['sigma_'+direction+'_final_Err'],                
                color=color, marker=marker,markersize=markersize,linewidth=linewidth
                , fmt=fmt,label=label)

def plot_calculation_line( data , varx='A',kind='nearest' , vary=None , color='blue' ,linestyle='--', label=None, linewidth=4):
    x = data[varx]
    y = data[vary]
    itp = interp1d(x,y, kind='linear')
    if kind is None:
        f = interp1d( x , y )
    else:
        f = interp1d( x , y ,kind=kind)
    window_size, poly_order = 101, 4
    xnew = np.linspace(x.min(),x.max(), num=500, endpoint=True)
    yy_sg = savgol_filter(itp(xnew), window_size, poly_order)
    plt.plot( xnew, yy_sg, linestyle, color=color , label=label, linewidth=linewidth )

# %%
def plot_needed_for_A_depdendence_sigma_t(ax=None,figsize=(16,15),s=30,
                                          xlim=(2.5,250), ylim=(79,200), 
                                          labels=dict({'$^4$He':(3.5,122),
                                                '$^{12}$C':(9,165),
                                                '$^{27}$Al':(21,182),
                                                '$^{56}$Fe':(45,185),
                                                '$^{208}$Pb':(140,184),                                               
                                                      }),
                                          fontsize=55,
                                          do_Ciofi=True):
    if ax is None:
        fig, ax = plt.subplots(figsize=figsize)
    # for all plots
    plot_calculation_line( kind='slinear',data=ColleCalc, varx='A' , vary='allpairs',color='black' ,label='Colle et al., All pairs')
    plot_calculation_line( kind='slinear',data=ColleCalc, varx='A' ,linestyle='-',color='black', vary='nl00',label='Colle et al., $^1S_0$ pairs')
    if do_Ciofi: ax.errorbar(CiofiCalc.A, CiofiCalc.s_t,markeredgecolor='black',marker='*',ms=30,mfc='none',linewidth=0, markeredgewidth=2,label='Ciofi and Simula')
    plot_data( data=BNL_Data, ax=ax, Ashift=1 , color='blue', marker='s', label=None )
    plot_data( data=HallA_Data, ax=ax, Ashift=-1 , color='blue' , marker='s' , label='Hall-A/BNL' )
    plot_data( data=Korover_Data , ax=ax, marker='s' , color='blue', label=None )
    
    ax.set_xscale('log')
    set_axes(ax , 'A' , '$\sigma_{c.m.}$ [GeV/c]' , fontsize=fontsize 
             ,xticks=[4,12,27,56,208]
             ,yticks=[100,125,150,175,200])
    ax.grid(b=True, which='major', color='b', linestyle='--',alpha=0.25)    
    if xlim is not None:    ax.set_xlim(xlim);
    if ylim is not None:    ax.set_ylim(ylim);
    # target name labels
    for label in list(labels.keys()):
        ax.text(labels[label][0],labels[label][1],label,fontsize=35)
    return ax

def plot_A_depdendence_sigma_t(data=cm_parameters_with_correction['PrecFiducials'],
                               figsize=(16,15),s=30,fontsize=55,
                               xlim=(2.5,250), ylim=(79,200), 
                               do_save_fig=True, filename='corrected_sigma_t_with_calculations',
                               labels=dict({'$^4$He':(3.5,122), '$^{12}$C':(9,165), '$^{27}$Al':(21,182),
                                            '$^{56}$Fe':(45,185), '$^{208}$Pb':(140,184), }),
                               do_Ciofi=True,do_measured=True,
                               do_stat_uncertainties=False,do_sys_uncertainties=False,do_tot_uncertainties=True):
    
    fig,ax = plt.subplots(figsize=figsize)
    ax=plot_needed_for_A_depdendence_sigma_t(ax=ax,figsize=figsize,fontsize=fontsize,s=s,xlim=xlim, ylim=ylim,labels=labels,do_Ciofi=do_Ciofi)
    # measured
    if do_measured: ax.plot(cm_pars['A'], 1000*cm_pars['sigma_t'] ,mec='red' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='This work, no acceptance corr.')
    # corrected
    if do_tot_uncertainties:
        plot_data( data=data, ax=ax, label='This work', markersize=20 ,color='red' , marker='o')
        
    # seperated statistical uncertainty
    if do_stat_uncertainties: 
        if do_tot_uncertainties:
            ax.errorbar(cm_pars['A'], 1000*data['sigma_t_final'], 1000*data['sigma_t_final_Err_stat'] 
                                          ,ecolor='purple',elinewidth=2 , capsize=15, capthick=3 , linestyle='none'
                                          ,linewidth=3, label='stat. uncertainties')
        else: 
            ax.errorbar(cm_pars['A'], 1000*data['sigma_t_final'], 1000*data['sigma_t_final_Err_stat'] 
                                          ,ecolor='red',color='red', marker='o', markersize=20 ,elinewidth=2 , capsize=15, capthick=3 , linestyle='none'
                                          ,linewidth=3, label='stat. uncertainties')

#     ax.legend(fontsize=25,loc='lower right')

    # add a band of systematical uncertaintes
    if do_sys_uncertainties:
        ax.fill_between(cm_pars['A']
                        , 100 - 1000*data['sigma_t_final_Err_sys']
                        , 100 + 1000*data['sigma_t_final_Err_sys'] 
                        , color='purple' , alpha=0.5 ,  label='sys. uncertainties')
    ax.legend(fontsize=25,loc='upper left')
        
    plt.tight_layout()
    if do_save_fig: plt.savefig( figures_path + filename + '.pdf'); print 'saved',figures_path + filename + '.pdf'

# %%
plot_A_depdendence_sigma_t(data=cm_parameters_with_correction['PrecFiducials']
                           ,figsize=(18,14)
                           ,do_stat_uncertainties=True,do_sys_uncertainties=True)
# Out:
# /usr/local/lib/python2.7/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/corrected_sigma_t_with_calculations.pdf

# %%
plot_A_depdendence_sigma_t(data=cm_parameters_with_correction['PrecFiducials'],filename='no_tot_uncertainties'
                           ,figsize=(18,14)
                           ,do_stat_uncertainties=True,do_sys_uncertainties=True,do_tot_uncertainties=False)
# Out:
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/no_tot_uncertainties.pdf

# %%
plot_A_depdendence_sigma_t(figsize=(13,9),data=cm_parameters_with_correction['PrecFiducials'],fontsize=35,
                           do_save_fig=False,do_measured=False)
plt.savefig('/Users/erezcohen/Desktop/Projects/2NSRC/ppCMpaper/fig2.png')

# %%
ax = plot_needed_for_A_depdendence_sigma_t(ylim=(79,210),labels=dict({'$^4$He':(3.5,122),
                                            '$^{12}$C':(9,165),
                                            '$^{27}$Al':(21,188),
                                            '$^{56}$Fe':(45,188),
                                            '$^{208}$Pb':(132,184),
                                           }))
ax.plot(cm_pars['A']+[-0.5,-0.7,-2,-3], cm_pars['sigma_x_unweighted'] ,mec='blue' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='$x$ no acceptance corr.')
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax, Ashift=[-0.5,-0.7,-2,-3] , direction='x', label='This work, x-direction', color='royalblue',markersize=20 )
ax.plot(cm_pars['A']+[0.5,0.7,2,3], cm_pars['sigma_y_unweighted'] ,mec='red' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='$y$ no acceptance corr.')
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax, Ashift=[0.5,0.7,2,3] ,direction='y', label='This work, y-direction', color='salmon', markersize=20 )
ax.legend(fontsize=25,loc='lower right')
plt.tight_layout()
plt.savefig( figures_path + 'corrected_sigma_xy_with_calculations.pdf')

# %%
ax = plot_needed_for_A_depdendence_sigma_t(ylim=(79,210),labels=dict({'$^4$He':(3.5,122),
                                            '$^{12}$C':(9,165), '$^{27}$Al':(21,182),
                                            '$^{56}$Fe':(45,192), '$^{208}$Pb':(135,184), }))
plot_data( data=WI_Data, ax=ax,label='results in WI',Ashift=[2,2,3,10],  markersize=20 , marker='s', color='black')
plot_data( data=cm_parameters_with_correction['PrecFiducials'],ax=ax, label='results $0.3<p_{miss}<0.6$ GeV/c', marker='o', markersize=20 )
ax.legend(fontsize=25, loc='lower right')
plt.tight_layout()
plt.savefig( figures_path + 'corrected_sigma_t_vs_WI_results.pdf')

# %% [markdown]
# # comparison between Fiducial cuts and no Fiducial cuts

# %%
# comparison between analysis w/ fiducial cuts on the Precoil and analysis w/o them
# note that in the analysis w/o fiducial cuts, the simulation assumed 3\sigma around measured values
# and w/ fiducial cuts assumed 5\sigma around measured values
ax = plot_needed_for_A_depdendence_sigma_t(ylim=(79,230),labels=dict({'$^4$He':(3.5,122),
                                            '$^{12}$C':(9,165), '$^{27}$Al':(21,188),
                                            '$^{56}$Fe':(45,188), '$^{208}$Pb':(132,184), }),do_Ciofi=False)
ax.plot(cm_pars['A']+[-0.5,-0.7,-2,-3], cm_pars['sigma_x_unweighted'] ,mec='blue' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='$x$ no acceptance corr.')
plot_data( data=cm_parameters_with_correction['PrecFiducials'],ax=ax, Ashift=[-0.5,-0.7,-2,-3] , direction='x', label='$\\hat{x}$, w/ Fid. cuts', color='royalblue',markersize=20  )
plot_data( data=cm_parameters_with_correction['NoPrecFiducials'], ax=ax,Ashift=[-1.2,-2.5,-6,-12] , direction='x', label='$\\hat{x}$, no Fid. cuts', color='blue',markersize=20 , marker=7)
ax.plot(cm_pars['A']+[0.5,0.7,2,3], cm_pars['sigma_y_unweighted'] ,mec='red' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='$y$ no acceptance corr.')
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[0.5,0.7,2,3] ,direction='y', label='$\\hat{y}$, w/ Fid. cuts', color='salmon', markersize=20 )
plot_data( data=cm_parameters_with_correction['NoPrecFiducials'], ax=ax,Ashift=[1.2,2.5,6,12] , direction='y', label='$\\hat{y}$, no Fid. cuts', color='tomato',markersize=20 , marker=7)
ax.legend(fontsize=25,loc='lower right')
# ax.plot(cm_pars['A']+[0.5,0.7,2,3], cm_pars['sigma_y_unweighted'] ,color='red', marker='s',mfc='none',lw = 2, mew = 2, ms = 10, linewidth=0)
plt.tight_layout()
plt.savefig( figures_path + 'corrected_sigma_xy_with_calculations_PrecFiducials_vs_NoPrecFiducials.pdf')

# %% [markdown]
# # compare constant band around mean(z) & \sigma(z) with 5 $\times \Delta_{measured}$

# %%
fig = plt.figure(figsize=(16,12))
ax = fig.add_subplot(2,1,1)
ax.errorbar(x=cm_pars['A'],y=cm_pars['mean_z_unweighted'],yerr=cm_pars['mean_zErr_unweighted'],fmt='s'
            ,color='blue',label='measured $\\mu_{\\vec{p}_{miss}}$')
ax.fill_between(cm_pars['A']
                ,cm_pars['mean_z_unweighted']-0.075
                ,cm_pars['mean_z_unweighted']+0.075
                ,color='royalblue',alpha=0.2,label='75 MeV/c around measured value')

set_axes(ax,'','$\\mu_{miss}$ [GeV/c]')
ax.xaxis.set_ticks([12,27,56,208]);ax.yaxis.set_ticks([0.05,0.15,0.25,0.35]);
ax.grid(linestyle='--',alpha=0.8)
plt.plot(cm_pars['A'],cm_pars['mean_z_unweighted']-5*cm_pars['mean_zErr_unweighted'],'--',linewidth=3,color='royalblue',label='5$\\sigma$ around measured value')
ax.legend(fontsize=25,loc='upper left')
plt.plot(cm_pars['A'],cm_pars['mean_z_unweighted']-0.075,'-',linewidth=3,color='royalblue')
plt.plot(cm_pars['A'],cm_pars['mean_z_unweighted']+0.075,'-',linewidth=3,color='royalblue')
plt.plot(cm_pars['A'],cm_pars['mean_z_unweighted']+5*cm_pars['mean_zErr_unweighted'],'--',linewidth=3,color='royalblue')


ax.xaxis.set_major_formatter(NullFormatter())
ax.set_xlim(0,250);ax.set_ylim(0.02,0.32);

ax = fig.add_subplot(2,1,2)
ax.errorbar(x=cm_pars['A'],y=cm_pars['sigma_z_unweighted'],yerr=cm_pars['sigma_zErr_unweighted'],fmt='s'
            ,color='blue',label='measured $\\sigma_{\\vec{p}_{miss}}$')
ax.fill_between(cm_pars['A'] ,cm_pars['sigma_z_unweighted']-0.05 ,cm_pars['sigma_z_unweighted']+0.05
                ,color='royalblue',alpha=0.2,label='50 MeV/c around measured value')

set_axes(ax,'A','$\\sigma_{c.m.}$ [GeV/c]')
ax.xaxis.set_ticks([12,27,56,208]);ax.yaxis.set_ticks([0.08,0.12,0.16,0.20,0.24]);
ax.grid(linestyle='--',alpha=0.8)
plt.plot(cm_pars['A'],cm_pars['sigma_z_unweighted']-5*cm_pars['sigma_zErr_unweighted'],'--',linewidth=3,color='royalblue',label='5$\\sigma$ around measured value')
ax.legend(fontsize=25,loc='upper left')
plt.plot(cm_pars['A'],cm_pars['sigma_z_unweighted']-0.05,'-',linewidth=3,color='royalblue')
plt.plot(cm_pars['A'],cm_pars['sigma_z_unweighted']+0.05,'-',linewidth=3,color='royalblue')
plt.plot(cm_pars['A'],cm_pars['sigma_z_unweighted']+5*cm_pars['sigma_zErr_unweighted'],'--',linewidth=3,color='royalblue')


ax.set_xlim(0,250);ax.set_ylim(0.07,0.27);


plt.tight_layout()
outfilename = figures_path + 'mean_sigma_z_Adependence_constant_band_around_measured.pdf'
print 'saved',outfilename
plt.savefig(outfilename)
# Out:
# saved /Users/erezcohen/Desktop/Projects/2NSRC/InternalCMNote/Figures/sigma_t_correction/mean_sigma_z_Adependence_constant_band_around_measured.pdf

# %%
extraname="_mean75MeVc_sigma50MeVc"
cm_parameters_with_correction['PrecFiducials'][['sigma_x'+extraname+'_final','sigma_x'+extraname+'_final_Err','sigma_x_corrected','sigma_x_corrected_err']]
# Out:
#    sigma_x_mean75MeVc_sigma50MeVc_final  \
# 0                              0.147317
# 1                              0.168534
# 2                              0.164036
# 3                              0.179313
#
#    sigma_x_mean75MeVc_sigma50MeVc_final_Err  sigma_x_corrected  \
# 0                                  0.010147           0.147566
# 1                                  0.017918           0.168377
# 2                                  0.012706           0.163984
# 3                                  0.024954           0.181228
#
#    sigma_x_corrected_err
# 0               0.008184
# 1               0.017194
# 2               0.010431
# 3               0.027181

# %%
extraname="_mean75MeVc_sigma50MeVc"

# comparison between analysis w/ fiducial cuts on the Precoil 
# with mean = 75 MeV/c and \sigma=50 MeV/c constant
# vs. 5\sigma around measured values
ax = plot_needed_for_A_depdendence_sigma_t(ylim=(79,210),labels=dict({'$^4$He':(3.5,122),
                                            '$^{12}$C':(9,165), '$^{27}$Al':(21,194),
                                            '$^{56}$Fe':(45,192), '$^{208}$Pb':(128,190), }),do_Ciofi=False)

ax.plot(cm_pars['A']+[-0.5,-0.7,-2,-3], cm_pars['sigma_x_unweighted'] ,mec='blue' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='$x$ no acceptance corr.')
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[-0.5,-0.7,-2,-3] , direction='x', label='$\\hat{x}$, 5$\\sigma$ around measured value', color='royalblue',markersize=20  )
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[-1.2,-2.5,-6,-12] , direction='x'+extraname, label='$\\hat{x}$, constant longitudinal mean and width', color='blue',markersize=20 , marker=7  )

ax.plot(cm_pars['A']+[0.5,0.7,2,3], cm_pars['sigma_y_unweighted'] ,mec='red' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='$y$ no acceptance corr.')
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[0.5,0.7,2,3] ,direction='y', label='$\\hat{y}$, 5$\\sigma$ around measured value', color='salmon', markersize=20 )
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[1.2,2.5,6,12] ,direction='y'+extraname, label='$\\hat{y}$, constant longitudinal mean and width',color='tomato',markersize=20 , marker=7 )

ax.legend(fontsize=25,loc='lower right')
ax.grid(b=True, which='major', color='b', linestyle='--',alpha=0.25)
plt.tight_layout()
plt.savefig( figures_path + 'corrected_sigma_xy_with_calculations_PrecFiducials_5Sigma_vs_ConstMeanZSigmaZ.pdf')

# %% [markdown]
# # compare mean(z) linear in $p_{miss}$ (slope$\times(p_{miss}-0.3)$) with 5 $\times \Delta_{measured}$

# %%
extraname="_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured"
cm_parameters_with_correction['PrecFiducials'][['sigma_x'+extraname+'_final','sigma_x'+extraname+'_final_Err','sigma_x_corrected','sigma_x_corrected_err']]
# Out:
#    sigma_x_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured_final  \
# 0                                           0.144146
# 1                                           0.165271
# 2                                           0.162953
# 3                                           0.180172
#
#    sigma_x_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured_final_Err  \
# 0                                           0.007411
# 1                                           0.014616
# 2                                           0.009426
# 3                                           0.022113
#
#    sigma_x_corrected  sigma_x_corrected_err
# 0           0.147566               0.008184
# 1           0.168377               0.017194
# 2           0.163984               0.010431
# 3           0.181228               0.027181

# %%
extraname="_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured"

# comparison between analysis w/ fiducial cuts on the Precoil 
# with mean(z) = slope X (p_miss-0.3) and sigma(z) is 5\sigma around measured values
# and analysis with mean(z) and sigma(z) both are 5\sigma around measured values

ax = plot_needed_for_A_depdendence_sigma_t(ylim=(79,230),labels=dict({'$^4$He':(3.5,122),
                                            '$^{12}$C':(9,165), '$^{27}$Al':(21,194),
                                            '$^{56}$Fe':(45,192), '$^{208}$Pb':(125,194), }),do_Ciofi=False)

ax.plot(cm_pars['A']+[-0.5,-0.7,-2,-3], cm_pars['sigma_x_unweighted'] ,mec='blue' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='$x$ no acceptance corr.')
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[-0.5,-0.7,-2,-3] , direction='x', label='$\\hat{x}$, 5$\\sigma$ around measured value', color='royalblue',markersize=20  )
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[-1.2,-2.5,-6,-12] , direction='x'+extraname, label='$\\hat{x}$, $\\mu_{miss}=a(p_{miss}-0.3)$', color='blue',markersize=20 , marker=7  )

ax.plot(cm_pars['A']+[0.5,0.7,2,3], cm_pars['sigma_y_unweighted'] ,mec='red' , marker='^' ,mfc='none',lw = 2, mew = 2, ms = 20, linewidth=0, label='$y$ no acceptance corr.')
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[0.5,0.7,2,3] ,direction='y', label='$\\hat{y}$, 5$\\sigma$ around measured value', color='salmon', markersize=20 )
plot_data( data=cm_parameters_with_correction['PrecFiducials'], ax=ax,Ashift=[1.2,2.5,6,12] ,direction='y'+extraname, label='$\\hat{y}$, $\\mu_{miss}=a(p_{miss}-0.3)$',color='tomato',markersize=20 , marker=7 )

ax.legend(fontsize=25,loc='lower right')
plt.tight_layout()
plt.savefig( figures_path + 'corrected_sigma_xy_with_calculations_PrecFiducials_5Sigma_vs_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured.pdf')

# %% [markdown]
# # compare altogether

# %%
ax = plot_needed_for_A_depdendence_sigma_t(ylim=(79,205),labels=dict({'$^4$He':(3.5,122),
                                            '$^{12}$C':(9,165), '$^{27}$Al':(21,182),
                                            '$^{56}$Fe':(45,192), '$^{208}$Pb':(128,188), }),do_Ciofi=False)

ax.errorbar(WI_Data['A']+[2,2,3,10], 1000*WI_Data['sigma_t_final'], 1000*WI_Data['sigma_t_final_Err'] ,mec='black', linestyle='none', marker='s',mfc='none',lw = 2, mew = 2, ms = 20, linewidth=1, label='results in WI')
plot_data( data=cm_parameters_with_correction['PrecFiducials'],ax=ax, label='nominal simualtions (5$\\sigma$ around measured values)', marker='o', markersize=20 )
plot_data( data=cm_parameters_with_correction['PrecFiducials'],ax=ax,direction='t_MeanZlinearInPmiss_SigmaZ5stdSroundMeasured' ,
          Ashift=[0.8,2.5,5,11], label='$\\mu_{miss}=a(p_{miss}-0.3)$', color='teal',markersize=20 , marker='s')
plot_data( data=cm_parameters_with_correction['PrecFiducials'],ax=ax,direction='t_mean75MeVc_sigma50MeVc' ,
          Ashift=[-0.6,-1.6,-3,-8], label='75[50] MeV/c around $\\mu_{miss}$[$\\sigma_{miss}$]', color='royalblue',markersize=20 , marker=6)
ax.legend(fontsize=25, loc='lower right')
plt.tight_layout()
plt.savefig( figures_path + 'corrected_sigma_t_vs_WI_and_all_other_methods_results.pdf')
