# %%
import sys; sys.path.insert(0,'../')
from notebook_tools import *
# %matplotlib inline

# %% [markdown]
# # load data

# %%
sims500 = pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/results/runs500000_results.csv')

# %% [markdown]
# sims500 = sims500[sims500.genSigmaZa1 < 0.65]
# simsrepair = pd.read_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/results/runs1095772_results.csv')
# sims500 = pd.concat([sims500,simsrepair])
# sims500.to_csv('/Users/erezcohen/Desktop/DataMining/Analysis_DATA/ppSRCcm/results/runs500000_results.csv')

# %% [markdown]
# # sigma_t

# %%
weights = sims500.PvalTotal_allPvals_12C

fig = plt.figure(figsize=(20,30))
ax = fig.add_subplot(3,2,1)
plot_2d_hist(sims500.genSigmaX , sims500.genSigmaZa1 , xlabel='$\sigma_t$ [GeV/c]', ylabel='$a_1$', weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

ax = fig.add_subplot(3,2,2)
plot_2d_hist(sims500.genSigmaX , sims500.genSigmaZa2, xlabel='$\sigma_t$ [GeV/c]', ylabel='$a_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

ax = fig.add_subplot(3,2,3)
plot_2d_hist(sims500.genSigmaX , sims500.genMeanZa1, xlabel='$\sigma_t$ [GeV/c]', ylabel='$b_1$' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)


ax = fig.add_subplot(3,2,4)
plot_2d_hist(sims500.genSigmaX , sims500.genMeanZa2, xlabel='$\sigma_t$ [GeV/c]', ylabel='$b_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

ax = fig.add_subplot(3,2,5)
plot_2d_hist(sims500.genSigmaZa1 , sims500.genSigmaZa2, xlabel='$a_1$', ylabel='$a_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

ax = fig.add_subplot(3,2,6)
plot_2d_hist(sims500.genMeanZa1 , sims500.genMeanZa2, xlabel='$b_1$', ylabel='$b_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

# %%
def plot_weighted_variable(data=sims500,var='SigmaX',x_label='$\sigma_t$ [GeV/c]',bins=15):
    weights = data['PvalTotal_allPvals_12C']
#     weights = data['PvalTotal_allPvals_12C']

    fig,ax=plt.subplots(figsize=(8,6))
    h,bins,_= plt.hist(data['gen'+var], bins=bins, histtype='step', linewidth=3, normed=1);
    h,bins,_= plt.hist(data['gen'+var], weights=weights , bins=bins, histtype='step', linewidth=3, normed=1);
    set_axes(ax,x_label=x_label, y_label='')
    mean = np.average(data['gen'+var], weights=weights)
    std = np.sqrt( np.average( np.square(data['gen'+var] - mean), weights=weights ) )
    ax.set_title('weighted average: $%.3f \pm %.3f$'%(mean,std) , fontsize=20,y=1.02)

# %%
plot_weighted_variable(data=sims500,var='SigmaX',x_label='$\sigma_t$ [GeV/c]',bins=15)
plot_weighted_variable(data=sims500,var='SigmaZa1',x_label='$a_1$ ',bins=15)
plot_weighted_variable(data=sims500,var='SigmaZa2',x_label='$a_2$ [GeV/c]',bins=15)
plot_weighted_variable(data=sims500,var='MeanZa1',x_label='$b_1$',bins=15)
plot_weighted_variable(data=sims500,var='MeanZa2',x_label='$b_2$ [GeV/c]',bins=15)

# %%
weights = sims500.PvalTotal_allPvals_12C
h,bins,_= plot_1d_hist(sims500.genSigmaX, xlabel='$\sigma_t$ [GeV/c]', ylabel='', weights=weights , bins=15);
mean = np.average()
plt.text(bins[5],0.8*np.max(h),'$%3f \pm %.3f$'%(mean,std))



# fig = plt.figure(figsize=(20,30))

# ax = fig.add_subplot(3,2,2)
# plot_2d_hist(sims500.genSigmaX , sims500.genSigmaZa2, xlabel='$\sigma_t$ [GeV/c]', ylabel='$a_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
# ax.grid(linestyle='--',alpha=0.5)

# ax = fig.add_subplot(3,2,3)
# plot_2d_hist(sims500.genSigmaX , sims500.genMeanZa1, xlabel='$\sigma_t$ [GeV/c]', ylabel='$b_1$' , weights=weights , ax=ax , bins=15);
# ax.grid(linestyle='--',alpha=0.5)


# ax = fig.add_subplot(3,2,4)
# plot_2d_hist(sims500.genSigmaX , sims500.genMeanZa2, xlabel='$\sigma_t$ [GeV/c]', ylabel='$b_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
# ax.grid(linestyle='--',alpha=0.5)

# ax = fig.add_subplot(3,2,5)
# plot_2d_hist(sims500.genSigmaZa1 , sims500.genSigmaZa2, xlabel='$a_1$', ylabel='$a_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
# ax.grid(linestyle='--',alpha=0.5)

# ax = fig.add_subplot(3,2,6)
# plot_2d_hist(sims500.genMeanZa1 , sims500.genMeanZa2, xlabel='$b_1$', ylabel='$b_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
# ax.grid(linestyle='--',alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f066618fb459> in <module>()
#       1 weights = sims500.PvalTotal_allPvals_12C
# ----> 2 h,bins,_= plot_1d_hist(sims500.genSigmaX, xlabel='$\sigma_t$ [GeV/c]', ylabel='', weights=weights , bins=15);
#       3 mean = np.average()
#       4 plt.text(bins[5],0.8*np.max(h),'$%3f \pm %.3f$'%(mean,std))
#       5
#
# ValueError: too many values to unpack

# %%
weights = None

fig = plt.figure(figsize=(20,30))
ax = fig.add_subplot(3,2,1)
plot_2d_hist(sims500.genSigmaX , sims500.genSigmaZa1 , xlabel='$\sigma_t$ [GeV/c]', ylabel='$a_1$', weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

ax = fig.add_subplot(3,2,2)
plot_2d_hist(sims500.genSigmaX , sims500.genSigmaZa2, xlabel='$\sigma_t$ [GeV/c]', ylabel='$a_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

ax = fig.add_subplot(3,2,3)
plot_2d_hist(sims500.genSigmaX , sims500.genMeanZa1, xlabel='$\sigma_t$ [GeV/c]', ylabel='$b_1$' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)


ax = fig.add_subplot(3,2,4)
plot_2d_hist(sims500.genSigmaX , sims500.genMeanZa2, xlabel='$\sigma_t$ [GeV/c]', ylabel='$b_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

ax = fig.add_subplot(3,2,5)
plot_2d_hist(sims500.genSigmaZa1 , sims500.genSigmaZa2, xlabel='$a_1$', ylabel='$a_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

ax = fig.add_subplot(3,2,6)
plot_2d_hist(sims500.genMeanZa1 , sims500.genMeanZa2, xlabel='$b_1$', ylabel='$b_2$ [GeV/c]' , weights=weights , ax=ax , bins=15);
ax.grid(linestyle='--',alpha=0.5)

# %%
sample = sims500[(sims500.recSigmaZa1_unweighted>-1) & (sims500.recMeanZa2_unweighted>-1)]

# %%
weights = sample.PvalSigmaZa2_unweighted_208Pb
plt.hist(sample.genSigmaZa2,weights=weights,bins=15);

# %%
plt.hist(sample.PvalTotal_allPvals_56Fe,bins=100,linewidth=3);
plt.semilogy()
# Out:
# []
